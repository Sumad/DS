# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np

# %%
langs = {'Python' : 56,
        'Java' : 34,
        'SQL': 39,
        'JavaScript': 29, 
        'C++' : 34
        }

# %%
series = pd.Series(langs).sort_values(ascending = True)
series
# Out:
# JavaScript    29
# C++           34
# Java          34
# SQL           39
# Python        56
# dtype: int64

# %%
series.values
# Out:
# array([29, 34, 34, 39, 56])

# %%
plt.figure()
plt.barh(y = series.index,width = series.values, height = 0.3, color = 'blue' )
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 5 artists>
